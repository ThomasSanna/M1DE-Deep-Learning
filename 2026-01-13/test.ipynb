# %%
import pandas as pd
import numpy as np
from keras.datasets import mnist
import seaborn as sns
import matplotlib.pyplot as plt
from keras.layers import Dense, Input, Flatten
from keras.models import Sequential
from keras.utils import to_categorical
import tensorflow as tf

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
#On normalise les données entre 0 et 1

# %%
vector_shape = 28*28
X_train = np.reshape(X_train, [-1, vector_shape])
X_test = np.reshape(X_test, [-1, vector_shape])

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
nu_hidden = 256

model = Sequential()
model.add(Input(shape=(784,)))
model.add(Dense(nu_hidden, activation='relu'))
model.add(Dense(nu_hidden, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_48 (Dense)                │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 269,322 (1.03 MB)
#  Trainable params: 269,322 (1.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=20, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9168 - loss: 0.2915 - val_accuracy: 0.9583 - val_loss: 0.1430
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9674 - loss: 0.1086 - val_accuracy: 0.9699 - val_loss: 0.1014
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9784 - loss: 0.0701 - val_accuracy: 0.9725 - val_loss: 0.0930
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9850 - loss: 0.0495 - val_accuracy: 0.9761 - val_loss: 0.0798
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9887 - loss: 0.0371 - val_accuracy: 0.9758 - val_loss: 0.0823
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9917 - loss: 0.0271 - val_accuracy: 0.9728 - val_loss: 0.0933
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9920 - loss: 0.0234 - val_accuracy: 0.9703 - val_loss: 0.1055
# Epoch 8/20
# ...

# %%
pd.DataFrame(history.history)
# Out:
#     accuracy      loss  val_accuracy  val_loss
# 0   0.898375  0.358733      0.953500  0.165186
# 1   0.958646  0.140243      0.961000  0.129934
# 2   0.970625  0.096671      0.968750  0.101813
# 3   0.978271  0.072741      0.972583  0.090264
# 4   0.983604  0.055466      0.971250  0.096979
# 5   0.986458  0.044552      0.975333  0.084962
# 6   0.988875  0.035119      0.972333  0.094436
# 7   0.991521  0.028653      0.974917  0.087977
# 8   0.992500  0.024018      0.976750  0.091680
# 9   0.994333  0.019478      0.973917  0.101758
# 10  0.995687  0.015147      0.975583  0.102570
# 11  0.994875  0.016181      0.974833  0.104310
# 12  0.996229  0.012553      0.974000  0.107020
# 13  0.995479  0.013078      0.977500  0.099826
# 14  0.996854  0.009976      0.975667  0.111430
# 15  0.997979  0.007130      0.975583  0.110362
# 16  0.995917  0.011822      0.971750  0.128309
# 17  0.997292  0.008166      0.978500  0.107795
# 18  0.996875  0.010339      0.972583  0.133020
# ...

# %%
y_pred = model.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# y_pred = np.array(y_pred).argmax(axis=1)
# y_test = np.array(y_test).argmax(axis=1)

# %%
y_test-y_pred == 0
# Out:
# array([ True,  True,  True, ...,  True,  True,  True], shape=(10000,))
